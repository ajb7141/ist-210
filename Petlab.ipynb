# %% [markdown]
# <a href="https://colab.research.google.com/github/nzp126/ist-210/blob/master/Petlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To explain this I'm going to break this down into parts  based on what our tables are and represent. We have created 6 tables and they consist of Food, Stock, FishID, Transactions, and Customers. FoodID because a majority of the business consists of people taking care of their already owned pets. In a pet store, if you have ever looked around, the store is split into sections and the largest being the food section. Buying a pet is the easy part but actually taking care of it and keeping it healthy is the opposite. Most people take their pets care very seriously and since every pet that the store sells is different in some nature, they will all need different food. In terms of stock, there needs to be a database to know what is in store and what needs to be ordered. Stock is very important to keep notice of because if a customer desperately needs a product and we say we have it and we don't, we're in big trouble. This is just an easier way to stay organized and keep things on a line. Fish is one of the catagories we debated adding but in the end it really is a whole different beast from having an air breathing pet. There's certain food, enclosures (aquariums), and grooming that fish need in general and so we wanted to separate them from the other animals in the store. Coming to the close, of course we're going to have transactions in order to start loyalty reward cards, send promotional emails, and to keep track of receipts.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
